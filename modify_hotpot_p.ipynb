# %%
import json
import numpy as np
import os
import pandas as pd
import simplejson
import string
from copy import deepcopy
from pprint import pprint
from tqdm import tqdm
import random
import matplotlib.pyplot as plt
import re

def normalize_answer(s):

    def remove_articles(text):
        return re.sub(r'\b(a|an|the)\b', ' ', text)

    def white_space_fix(text):
        return ' '.join(text.split())

    def remove_punc(text):
        exclude = set(string.punctuation)
        return ''.join(ch for ch in text if ch not in exclude)

    def lower(text):
        return text.lower()

    return white_space_fix(remove_articles(remove_punc(lower(s))))


DATA_DIR = '{}/research/data'.format(os.getenv('HOME'))
seed = 42

# %%
### Combine Q, sub-Qs, sub-As
# Read QIDs (to split between train/dev)
qid2example = {}
qid2split2example = {}
qid2final_answers = None
DATA_DIR = '{}/research/data'.format(os.getenv('HOME'))
for split in ['train', 'dev_distractor']:
    file_path = '{}/hotpot-orig/hotpot_{}_v1.json'.format(DATA_DIR, split)
    with open(file_path, 'r') as f:
        data_hotpot = json.load(f)
    splitqid2example = {example['_id']: example for example in data_hotpot}
    qid2example.update(splitqid2example)
    qid2split2example[split.replace('_distractor', '')] = splitqid2example

# Read data and predictions (Q, sub-Qs, sub-As, and context)
data_with_subqs = {'data': []}
subas = {}
num_shards = 500
base_name = 'filter_name=bi-cond-lm.top_knn=10.max_mods_per_nn=4'
for shard_no in range(num_shards):
    with open('{}/research/DecompRC/DecompRC/out/hotpot/bert_predict.retrieve_and_edit.split=train-dev.{}.num_shards={}.shard_no={}.nbest_predictions.json'.format(
            os.getenv('HOME'), base_name, num_shards, shard_no)) as f:
        subas.update(json.load(f))
    with open('{}/research/data/hotpot-all/split=train-dev.{}.num_shards={}.shard_no={}.json'.format(
            os.getenv('HOME'), base_name, num_shards, shard_no)) as f:
        data_with_subqs['data'] += json.load(f)['data']

data_hotpot_squad = {}
for split in ['train', 'dev_distractor']:
    file_path = '{}/hotpot-squad/hotpot_{}_v1.json'.format(DATA_DIR, split)
    with open(file_path, 'r') as f:
        data_hotpot_squad[split.replace('_distractor', '')] = json.load(f)

# %%
all_subqs = []
all_subas = []
for example in data_with_subqs['data']:
    for para in example['paragraphs']:
        subqas = para['qas']
        qid = subqas[0]['id'].split('-')[0]
        for s in range(len(subqas)):
            all_subqs.append(subqas[s]['question'].strip())
            all_subas.append(subas[qid + '-' + str(s)][0]['text'].strip())

# %%
# Process/combine data
use_q = False
use_subq = True
use_random_subq = False
use_suba = True
use_random_suba = False

subq_sep = '/'
random.seed(seed)
num_question_words = []
answer_lens = []
qid2q_subqs_subas = {}
for example in data_with_subqs['data']:
    for para in example['paragraphs']:
        question = para['original_question'].strip() if use_q else ''
        subqas = para['qas']
        qid = subqas[0]['id'].split('-')[0]
        if use_subq or use_suba:
            for s in range(len(subqas)):
                # NB: Can also extract: probability, logit, no_answer_logit, evidence
                subqid = qid + '-' + str(s)
                question += ' ' + subq_sep
                if use_subq:
                    subq = random.sample(all_subqs, 1)[0] if use_random_subq else subqas[s]['question']
                    question += ' ' + subq.strip()
                if use_suba:
                    suba = random.sample(all_subas, 1)[0] if use_random_suba else subas[subqid][0]['text']
                    question += ' ' + suba.strip()
        question = question.strip(' ' + subq_sep + ' ')
        qid2q_subqs_subas[qid] = question
        answer_lens.append(sum([1 for answer in qid2example[qid]['answer'] if len(answer) > 0]))
        num_question_words.append(len(question.split()))
num_question_words = np.array(num_question_words)
answer_lens = np.array(answer_lens)
print('# words in Q, sub-Qs, and sub-As: {:.2f}'.format(num_question_words.mean()))
print('answer lengths:', answer_lens.min(), answer_lens.mean(), answer_lens.max())
# Out:
# # words in Q, sub-Qs, and sub-As: 469.97
# answer lengths: 1 13.848710297183501 623

# %%
qid2q_subqs_subas['5a7a06935542990198eaf050']
# Out:
# "first for women magazine started? 1989 / arthur's magazine started? ready set go! / arthur's magazine magazine started? ready set go! / where was or first for? philadelphia / which university magazine is a started first arthur magazine? first for women / which university magazine is a first arthur's magazine? ready set go! / which university magazine is a first arthur magazine? ready set go! / which university magazine is was started first magazine? arthur's magazine / when was arthur's magazine magazine started? 1989 / when was first for women law magazine started? 19th century / when was the first for women law magazine started? 1844 / when was the magazine magazine started? 1989 / which university magazine is a started first arthur magazine? first for women / which university magazine is a first arthur's magazine? ready set go! / which university magazine is a first arthur magazine? ready set go! / which university magazine is a free started first arthur magazine? first for women / what arthur's magazine monestery? echosmith / what's magazine or monestery? echosmith / what was arthur's magazine? an american literary periodical / what was arthur's magazine monestery? an american literary periodical / magazine was started was the first to appear in a weekly magazine? no / which comic character was the first to arthur's magazine a weekly magazine? ready set go! / which comic character was the first to appear magazine was started magazine? godey's lady's book / which magazine or first the first to appear in a weekly magazine? arthur's magazine / in what year was the times'travel magazine arthur's magazine? 2009 / in what year was the times'travel arthur's magazine? 2009 / in started first arthur year was the times'travel magazine first sold? no / in arthur's magazine was the times'travel magazine first sold? no / what was schuenemann magazine or? arthur's magazine / what was schuenemann arthur's magazine? an american literary periodical / what was schuenemann magazine was started? ready set go! / what was schuenemann which magazine? arthur's magazine / what is a magazine for design arthur's magazine? echosmith / what is a magazine for design's magazine or? arthur's magazine / arthur's magazine invloved in the polonization? echosmith / 's magazine or invloved in the polonization? arthur's magazine / arthur's magazine first invloved in the polonization? ready set go! / magazine or invloved in the polonization? arthur's magazine"

# %%
answer_f1s = []
data_hotpot_squad_new = deepcopy(data_hotpot_squad)
for split in data_hotpot_squad_new.keys():
    print('split:', split)
    for example_no in tqdm(range(len(data_hotpot_squad_new[split]['data']))):
        if '_id' not in data_hotpot_squad_new[split]['data'][example_no]['paragraphs'][0]:
            continue # SQuAD example: No modification necessary
        # Treat input (Qs, sub-Qs, and sub-As) all as one paragraph
        data_hotpot_squad_new[split]['data'][example_no]['paragraphs'] = data_hotpot_squad_new[split]['data'][example_no]['paragraphs'][:1]
        qid = data_hotpot_squad_new[split]['data'][example_no]['paragraphs'][0]['_id']
        if qid in qid2q_subqs_subas.keys():
            data_hotpot_squad_new[split]['data'][example_no]['paragraphs'][0]['context'] = 'yes no ' + qid2q_subqs_subas[qid].strip().lower()
        
        # Find answer text in Qs, sub-Qs, and sub-As
        answer_text = qid2split2example[split][qid]['answer'].lower().strip()
        answer_start = None
        answer_words = answer_text.split()
        answer_f1 = 0.
        for span_len in range(len(answer_words), 0, -1):
            for answer_word_start_index in range(len(answer_words) - span_len + 1):
                answer_text_slice = ' '.join(answer_words[answer_word_start_index: answer_word_start_index + span_len])
                if answer_text_slice in {'a', 'an', 'the'}:
                    continue  # Exclude articles as SQuAD evaluation does
                if answer_text_slice in data_hotpot_squad_new[split]['data'][example_no]['paragraphs'][0]['context']:
                    answer_start = data_hotpot_squad_new[split]['data'][example_no]['paragraphs'][0]['context'].index(answer_text_slice)
                    answer_prec = 1.
                    answer_recall = span_len / float(len(answer_words))
                    answer_f1 = 2 * (answer_prec * answer_recall) / (answer_prec + answer_recall)
                    break
            if answer_start is not None:
                break
        answer_f1s.append(answer_f1)
        assert len(data_hotpot_squad_new[split]['data'][example_no]['paragraphs'][0]['qas']) == 1
        data_hotpot_squad_new[split]['data'][example_no]['paragraphs'][0]['qas'][0]['answers'] = [{'text': answer_text_slice, 'answer_start': answer_start}] if answer_start is not None else []
        data_hotpot_squad_new[split]['data'][example_no]['paragraphs'][0]['qas'][0]['is_impossible'] = answer_start is None
        if not use_q:
            data_hotpot_squad_new[split]['data'][example_no]['paragraphs'][0]['qas'][0]['question'] = '?'
pprint(data_hotpot_squad_new['dev']['data'][0]['paragraphs'])
answer_f1s = np.array(answer_f1s)
print('Max F1:', answer_f1s.mean())
print('Max EM:', (answer_f1s == 1.).mean())  # 71044: 1 EM, 26808: 0 EM
# Out:
#   4%|▍         | 3839/90889 [00:00<00:02, 38388.57it/s]
# split: train
# 100%|██████████| 90889/90889 [00:02<00:00, 41107.91it/s]
# 100%|██████████| 7440/7440 [00:00<00:00, 39288.97it/s]
# split: dev
# [{'_id': '5a8b57f25542995d1e6f1371',
#   'context': 'yes no derrickson the dorsland trekkers? conrad brooks / what '
#              'derrickson the dorsland trekkers? conrad brooks / derrickson and '
#              'were the dorsland trekkers? no / ed wood were the dorsland '
#              'trekkers? no / what is the derrickson and ed sergewa? filmmaker, '
#              'actor, writer, producer, and director / what is derrickson and '
#              'ed of seham sergewa? filmmaker, actor, writer, producer, and '
#              'director / what is the were scott derrickson sergewa? american '
#              'actor / what is the were scott derrickson seham sergewa? '
#              'american actor / derrickson and ed evlija chelebija? no / scott '
#              'derrickson evlija chelebija? conrad brooks / and ed wood evlija '
#              'chelebija? sinister / ed wood of evlija chelebija? tyler bates / '
#              'what was the were scott derrickson of ed policy? american '
#              'filmmaker / what was the scott derrickson and of ed policy? '
#              'filmmaker, actor, writer, producer, and director / what was '
#              'scott derrickson of ed policy? director / what was the scott '
#              'derrickson of ed policy? director / what derrickson and of? '
#              'conrad brooks / what does derrickson and of? american filmmaker '
#              '/ what does wood derrickson and of? american filmmaker / what '
#              'the same of? american filmmaker / what property of wood does a '
#              'knot usually reduce in the were scott derrickson? american '
#              'filmmaker / what property of wood does a knot scott derrickson '
#              'the wood around it? relationship / what property of wood does a '
#              'knot usually derrickson and ed the wood around it? american / '
#              'what property of wood does a knot usually derrickson and ed in '
#              'the wood around it? american filmmaker / when derrickson and ed '
#              'called the " wood " was actually made out of it, what type of '
#              'wood was used? american / when derrickson and ed club called the '
#              '" wood " was actually made out of it, what type of wood was '
#              'used? comedy-drama film / when scott derrickson called the " '
#              'wood " was actually made out of it, what type of wood was used? '
#              'american / when scott derrickson and club called the " wood " '
#              'was actually made out of it, what type of wood was used? '
#              'american / what type of were scott derrickson on the inside? '
#              'comedy-drama film / what were scott derrickson was used on the '
#              'inside? filmmaker, actor, writer, producer, and director / what '
#              'type were scott derrickson used on the inside? comedy-drama film '
#              '/ what were scott derrickson wood was used on the inside? '
#              'filmmaker, actor, writer, producer, and director / along with '
#              'strength, what property do wood derrickson and ed to wood? '
#              'director / along with strength, what property do wood were scott '
#              'derrickson to wood? producer, and director / along with '
#              'strength, what property do wood scott derrickson and wood? '
#              'director / along with strength, what property do wood scott '
#              'derrickson and to wood? director',
#   'level': 'hard',
#   'qas': [{'answers': [{'answer_start': 0, 'text': 'yes'}],
#            'id': '5a8b57f25542995d1e6f1371.0',
#            'is_impossible': False,
#            'question': '?'}],
#   'supporting_facts': [],
#   'type': 'comparison'}]
# Max F1: 0.7957689944711999
# Max EM: 0.7211298695989862

# %%
pprint(data_hotpot_squad_new['train']['data'][0]['paragraphs'])
# Out:
# [{'_id': '5a7a06935542990198eaf050',
#   'context': "yes no first for women magazine started? 1989 / arthur's "
#              "magazine started? ready set go! / arthur's magazine magazine "
#              'started? ready set go! / where was or first for? philadelphia / '
#              'which university magazine is a started first arthur magazine? '
#              "first for women / which university magazine is a first arthur's "
#              'magazine? ready set go! / which university magazine is a first '
#              'arthur magazine? ready set go! / which university magazine is '
#              "was started first magazine? arthur's magazine / when was "
#              "arthur's magazine magazine started? 1989 / when was first for "
#              'women law magazine started? 19th century / when was the first '
#              'for women law magazine started? 1844 / when was the magazine '
#              'magazine started? 1989 / which university magazine is a started '
#              'first arthur magazine? first for women / which university '
#              "magazine is a first arthur's magazine? ready set go! / which "
#              'university magazine is a first arthur magazine? ready set go! / '
#              'which university magazine is a free started first arthur '
#              "magazine? first for women / what arthur's magazine monestery? "
#              "echosmith / what's magazine or monestery? echosmith / what was "
#              "arthur's magazine? an american literary periodical / what was "
#              "arthur's magazine monestery? an american literary periodical / "
#              'magazine was started was the first to appear in a weekly '
#              "magazine? no / which comic character was the first to arthur's "
#              'magazine a weekly magazine? ready set go! / which comic '
#              'character was the first to appear magazine was started magazine? '
#              "godey's lady's book / which magazine or first the first to "
#              "appear in a weekly magazine? arthur's magazine / in what year "
#              "was the times'travel magazine arthur's magazine? 2009 / in what "
#              "year was the times'travel arthur's magazine? 2009 / in started "
#              "first arthur year was the times'travel magazine first sold? no / "
#              "in arthur's magazine was the times'travel magazine first sold? "
#              "no / what was schuenemann magazine or? arthur's magazine / what "
#              "was schuenemann arthur's magazine? an american literary "
#              'periodical / what was schuenemann magazine was started? ready '
#              "set go! / what was schuenemann which magazine? arthur's magazine "
#              "/ what is a magazine for design arthur's magazine? echosmith / "
#              "what is a magazine for design's magazine or? arthur's magazine / "
#              "arthur's magazine invloved in the polonization? echosmith / 's "
#              "magazine or invloved in the polonization? arthur's magazine / "
#              "arthur's magazine first invloved in the polonization? ready set "
#              "go! / magazine or invloved in the polonization? arthur's "
#              'magazine',
#   'level': 'medium',
#   'qas': [{'answers': [{'answer_start': 48, 'text': "arthur's magazine"}],
#            'id': '5a7a06935542990198eaf050.0',
#            'is_impossible': False,
#            'question': '?'}],
#   'supporting_facts': [],
#   'type': 'comparison'}]

# %%
pprint(data_hotpot_squad_new['dev']['data'][-1]['paragraphs'])
# Out:
# [{'context': 'Philosophers in antiquity used the concept of force in the study '
#              'of stationary and moving objects and simple machines, but '
#              'thinkers such as Aristotle and Archimedes retained fundamental '
#              'errors in understanding force. In part this was due to an '
#              'incomplete understanding of the sometimes non-obvious force of '
#              'friction, and a consequently inadequate view of the nature of '
#              'natural motion. A fundamental error was the belief that a force '
#              'is required to maintain motion, even at a constant velocity. '
#              'Most of the previous misunderstandings about motion and force '
#              'were eventually corrected by Galileo Galilei and Sir Isaac '
#              'Newton. With his mathematical insight, Sir Isaac Newton '
#              'formulated laws of motion that were not improved-on for nearly '
#              'three hundred years. By the early 20th century, Einstein '
#              'developed a theory of relativity that correctly predicted the '
#              'action of forces on objects with increasing momenta near the '
#              'speed of light, and also provided insight into the forces '
#              'produced by gravitation and inertia.',
#   'qas': [{'answers': [{'answer_start': 46, 'text': 'force'},
#                        {'answer_start': 46, 'text': 'force'},
#                        {'answer_start': 31, 'text': 'the concept of force'},
#                        {'answer_start': 31, 'text': 'the concept of force'},
#                        {'answer_start': 46, 'text': 'force'},
#                        {'answer_start': 46, 'text': 'force'}],
#            'id': '573735e8c3c5551400e51e71',
#            'is_impossible': False,
#            'question': 'What concept did philosophers in antiquity use to '
#                        'study simple machines?'},
#           {'answers': [{'answer_start': 387, 'text': 'fundamental error'},
#                        {'answer_start': 385, 'text': 'A fundamental error'},
#                        {'answer_start': 385, 'text': 'A fundamental error'},
#                        {'answer_start': 385, 'text': 'A fundamental error'},
#                        {'answer_start': 385, 'text': 'A fundamental error'},
#                        {'answer_start': 385, 'text': 'A fundamental error'}],
#            'id': '573735e8c3c5551400e51e72',
#            'is_impossible': False,
#            'question': 'What was the belief that maintaining motion required '
#                        'force?'},
#           {'answers': [{'answer_start': 654, 'text': 'Sir Isaac Newton'},
#                        {'answer_start': 654, 'text': 'Sir Isaac Newton'},
#                        {'answer_start': 654, 'text': 'Sir Isaac Newton'},
#                        {'answer_start': 654, 'text': 'Sir Isaac Newton'},
#                        {'answer_start': 654, 'text': 'Sir Isaac Newton'},
#                        {'answer_start': 654, 'text': 'Sir Isaac Newton'}],
#            'id': '573735e8c3c5551400e51e73',
#            'is_impossible': False,
#            'question': 'Who had mathmatical insite?'},
#           {'answers': [{'answer_start': 727,
#                         'text': 'nearly three hundred years'},
#                        {'answer_start': 727,
#                         'text': 'nearly three hundred years'},
#                        {'answer_start': 727,
#                         'text': 'nearly three hundred years'},
#                        {'answer_start': 727,
#                         'text': 'nearly three hundred years'},
#                        {'answer_start': 727,
#                         'text': 'nearly three hundred years'},
#                        {'answer_start': 734, 'text': 'three hundred years'}],
#            'id': '573735e8c3c5551400e51e74',
#            'is_impossible': False,
#            'question': "How long did it take to improve on Sir Isaac Newton's "
#                        'laws of motion?'},
#           {'answers': [{'answer_start': 782, 'text': 'Einstein'},
#                        {'answer_start': 782, 'text': 'Einstein'},
#                        {'answer_start': 782, 'text': 'Einstein'},
#                        {'answer_start': 782, 'text': 'Einstein'},
#                        {'answer_start': 782, 'text': 'Einstein'},
#                        {'answer_start': 782, 'text': 'Einstein'}],
#            'id': '573735e8c3c5551400e51e75',
#            'is_impossible': False,
#            'question': 'Who develped the theory of relativity?'},
#           {'answers': [],
#            'id': '5ad25efad7d075001a428f56',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 0, 'text': 'Philosophers'}],
#            'question': 'Who used the concept of antiquity in the study of '
#                        'stationary and moving objects?'},
#           {'answers': [],
#            'id': '5ad25efad7d075001a428f57',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 377, 'text': 'motion'}],
#            'question': 'Something that is considered a non fundamental error '
#                        'is the belief that a force is required to maintain '
#                        'what?'},
#           {'answers': [],
#            'id': '5ad25efad7d075001a428f58',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 585,
#                                   'text': 'Galileo Galilei and Sir Isaac '
#                                           'Newton'}],
#            'question': 'Most of the previous understandings about motion and '
#                        'force were corrected by whom?'},
#           {'answers': [],
#            'id': '5ad25efad7d075001a428f59',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 539,
#                                   'text': 'motion and force'}],
#            'question': 'Sir Galileo Galilei corrected the previous '
#                        'misunderstandings about what?'},
#           {'answers': [],
#            'id': '5ad25efad7d075001a428f5a',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 654,
#                                   'text': 'Sir Isaac Newton'}],
#            'question': 'Who formulated the laws of motion that were not '
#                        'improved-on for nearly three thousand years?'}]},
#  {'context': 'With modern insights into quantum mechanics and technology that '
#              'can accelerate particles close to the speed of light, particle '
#              'physics has devised a Standard Model to describe forces between '
#              'particles smaller than atoms. The Standard Model predicts that '
#              'exchanged particles called gauge bosons are the fundamental '
#              'means by which forces are emitted and absorbed. Only four main '
#              'interactions are known: in order of decreasing strength, they '
#              'are: strong, electromagnetic, weak, and gravitational.:2–10:79 '
#              'High-energy particle physics observations made during the 1970s '
#              'and 1980s confirmed that the weak and electromagnetic forces are '
#              'expressions of a more fundamental electroweak interaction.',
#   'qas': [{'answers': [{'answer_start': 149, 'text': 'Standard Model'},
#                        {'answer_start': 149, 'text': 'Standard Model'},
#                        {'answer_start': 149, 'text': 'Standard Model'},
#                        {'answer_start': 149, 'text': 'Standard Model'},
#                        {'answer_start': 147, 'text': 'a Standard Model'},
#                        {'answer_start': 147, 'text': 'a Standard Model'}],
#            'id': '57373a9fc3c5551400e51e7b',
#            'is_impossible': False,
#            'question': 'What has partical physics made to describe sub-atomic '
#                        'forces?'},
#           {'answers': [{'answer_start': 281, 'text': 'gauge bosons'},
#                        {'answer_start': 281, 'text': 'gauge bosons'},
#                        {'answer_start': 281, 'text': 'gauge bosons'},
#                        {'answer_start': 281, 'text': 'gauge bosons'},
#                        {'answer_start': 281, 'text': 'gauge bosons'},
#                        {'answer_start': 281, 'text': 'gauge bosons'}],
#            'id': '57373a9fc3c5551400e51e7c',
#            'is_impossible': False,
#            'question': 'What are the exchanged particles predicted by the '
#                        'standard Model?'},
#           {'answers': [{'answer_start': 444, 'text': 'strong'},
#                        {'answer_start': 444, 'text': 'strong'},
#                        {'answer_start': 444, 'text': 'strong,'},
#                        {'answer_start': 444, 'text': 'strong'},
#                        {'answer_start': 444, 'text': 'strong'},
#                        {'answer_start': 444,
#                         'text': 'strong, electromagnetic'}],
#            'id': '57373a9fc3c5551400e51e7d',
#            'is_impossible': False,
#            'question': 'What is the strongest main interaction?'},
#           {'answers': [{'answer_start': 479, 'text': 'gravitational'},
#                        {'answer_start': 479, 'text': 'gravitational'},
#                        {'answer_start': 479, 'text': 'gravitational'},
#                        {'answer_start': 479, 'text': 'gravitational'},
#                        {'answer_start': 479, 'text': 'gravitational'},
#                        {'answer_start': 479, 'text': 'gravitational'}],
#            'id': '57373a9fc3c5551400e51e7e',
#            'is_impossible': False,
#            'question': 'What is the weakest main interaction?'},
#           {'answers': [{'answer_start': 665, 'text': 'electroweak interaction'},
#                        {'answer_start': 646,
#                         'text': 'a more fundamental electroweak interaction'},
#                        {'answer_start': 648,
#                         'text': 'more fundamental electroweak interaction.'},
#                        {'answer_start': 646,
#                         'text': 'a more fundamental electroweak interaction'},
#                        {'answer_start': 653,
#                         'text': 'fundamental electroweak interaction.'}],
#            'id': '57373a9fc3c5551400e51e7f',
#            'is_impossible': False,
#            'question': 'What are weak and electromatic forces expressions of?'},
#           {'answers': [],
#            'id': '5ad25f82d7d075001a428f84',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 26,
#                                   'text': 'quantum mechanics and technology'}],
#            'question': 'What can decelerate particles close to the speed of '
#                        'light?'},
#           {'answers': [],
#            'id': '5ad25f82d7d075001a428f85',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 176,
#                                   'text': 'forces between particles smaller '
#                                           'than atoms'}],
#            'question': 'Particle physics has created a Unique Model to '
#                        'describe what? '},
#           {'answers': [],
#            'id': '5ad25f82d7d075001a428f86',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 329,
#                                   'text': 'forces are emitted and absorbed'}],
#            'question': 'The Unique Model predicts that exchanged particles are '
#                        'the fundamental means by what?'},
#           {'answers': [],
#            'id': '5ad25f82d7d075001a428f87',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 367, 'text': 'four'}],
#            'question': 'How many main interactions are not know?'}]},
#  {'context': 'Aristotle provided a philosophical discussion of the concept of '
#              'a force as an integral part of Aristotelian cosmology. In '
#              "Aristotle's view, the terrestrial sphere contained four elements "
#              'that come to rest at different "natural places" therein. '
#              'Aristotle believed that motionless objects on Earth, those '
#              'composed mostly of the elements earth and water, to be in their '
#              'natural place on the ground and that they will stay that way if '
#              'left alone. He distinguished between the innate tendency of '
#              'objects to find their "natural place" (e.g., for heavy bodies to '
#              'fall), which led to "natural motion", and unnatural or forced '
#              'motion, which required continued application of a force. This '
#              'theory, based on the everyday experience of how objects move, '
#              'such as the constant application of a force needed to keep a '
#              'cart moving, had conceptual trouble accounting for the behavior '
#              'of projectiles, such as the flight of arrows. The place where '
#              'the archer moves the projectile was at the start of the flight, '
#              'and while the projectile sailed through the air, no discernible '
#              'efficient cause acts on it. Aristotle was aware of this problem '
#              "and proposed that the air displaced through the projectile's "
#              'path carries the projectile to its target. This explanation '
#              'demands a continuum like air for change of place in general.',
#   'qas': [{'answers': [{'answer_start': 0, 'text': 'Aristotle'},
#                        {'answer_start': 0, 'text': 'Aristotle'},
#                        {'answer_start': 0, 'text': 'Aristotle'},
#                        {'answer_start': 0, 'text': 'Aristotle'},
#                        {'answer_start': 0, 'text': 'Aristotle'},
#                        {'answer_start': 0, 'text': 'Aristotle'}],
#            'id': '57373d0cc3c5551400e51e85',
#            'is_impossible': False,
#            'question': 'Who provided a philosophical discussion of force?'},
#           {'answers': [{'answer_start': 95, 'text': 'Aristotelian cosmology'},
#                        {'answer_start': 95, 'text': 'Aristotelian cosmology'},
#                        {'answer_start': 95, 'text': 'Aristotelian cosmology'},
#                        {'answer_start': 95, 'text': 'Aristotelian cosmology'},
#                        {'answer_start': 108, 'text': 'cosmology'},
#                        {'answer_start': 95, 'text': 'Aristotelian cosmology'}],
#            'id': '57373d0cc3c5551400e51e86',
#            'is_impossible': False,
#            'question': 'What was the concept of force an integral part of?'},
#           {'answers': [{'answer_start': 173, 'text': 'four'},
#                        {'answer_start': 173, 'text': 'four'},
#                        {'answer_start': 173, 'text': 'four'},
#                        {'answer_start': 173, 'text': 'four'},
#                        {'answer_start': 173, 'text': 'four'},
#                        {'answer_start': 173, 'text': 'four'}],
#            'id': '57373d0cc3c5551400e51e87',
#            'is_impossible': False,
#            'question': 'How many elements did Aristotle believe the '
#                        'terrestrial sphere to be made up of?'},
#           {'answers': [{'answer_start': 381, 'text': 'on the ground'},
#                        {'answer_start': 388, 'text': 'ground'},
#                        {'answer_start': 540, 'text': 'heavy bodies to fall'},
#                        {'answer_start': 381, 'text': 'on the ground'},
#                        {'answer_start': 381, 'text': 'on the ground'},
#                        {'answer_start': 381, 'text': 'on the ground'}],
#            'id': '57373d0cc3c5551400e51e88',
#            'is_impossible': False,
#            'question': 'Where did Aristotle believe the natural place for '
#                        'earth and water elements?'},
#           {'answers': [{'answer_start': 598, 'text': 'unnatural'},
#                        {'answer_start': 598, 'text': 'unnatural'},
#                        {'answer_start': 577, 'text': 'natural motion'},
#                        {'answer_start': 598, 'text': 'unnatural'},
#                        {'answer_start': 641,
#                         'text': 'continued application of a force'},
#                        {'answer_start': 598, 'text': 'unnatural'}],
#            'id': '57373d0cc3c5551400e51e89',
#            'is_impossible': False,
#            'question': 'What did Aristotle refer to forced motion as?'},
#           {'answers': [],
#            'id': '5ad2605dd7d075001a428fc6',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 0, 'text': 'Aristotle'}],
#            'question': 'Who provided a discussion on the concept of time as an '
#                        'integral part of Aristotelian cosmology?'},
#           {'answers': [],
#            'id': '5ad2605dd7d075001a428fc7',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 173, 'text': 'four'}],
#            'question': "In Galileo's view, the terrestrial sphere contained "
#                        'how many elements?'},
#           {'answers': [],
#            'id': '5ad2605dd7d075001a428fc8',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 436, 'text': 'alone'}],
#            'question': 'Aristotle believed that objects in motion on Earth '
#                        'would stay that way if what?'},
#           {'answers': [],
#            'id': '5ad2605dd7d075001a428fc9',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 1085, 'text': 'Aristotle'}],
#            'question': 'Who proposed that water displaced through the '
#                        "projectile's path carries the projectile to its "
#                        'target?'}]},
#  {'context': 'The shortcomings of Aristotelian physics would not be fully '
#              'corrected until the 17th century work of Galileo Galilei, who '
#              'was influenced by the late Medieval idea that objects in forced '
#              'motion carried an innate force of impetus. Galileo constructed '
#              'an experiment in which stones and cannonballs were both rolled '
#              'down an incline to disprove the Aristotelian theory of motion '
#              'early in the 17th century. He showed that the bodies were '
#              'accelerated by gravity to an extent that was independent of '
#              'their mass and argued that objects retain their velocity unless '
#              'acted on by a force, for example friction.',
#   'qas': [{'answers': [{'answer_start': 80, 'text': '17th century'},
#                        {'answer_start': 80, 'text': '17th century'},
#                        {'answer_start': 80, 'text': '17th century'},
#                        {'answer_start': 76, 'text': 'the 17th century'},
#                        {'answer_start': 80, 'text': '17th century'},
#                        {'answer_start': 80, 'text': '17th century'}],
#            'id': '57373f80c3c5551400e51e8f',
#            'is_impossible': False,
#            'question': "When were the shortcomings of Aristotle's physics "
#                        'overcome?'},
#           {'answers': [{'answer_start': 101, 'text': 'Galileo Galilei'},
#                        {'answer_start': 101, 'text': 'Galileo Galilei'},
#                        {'answer_start': 101, 'text': 'Galileo Galilei'},
#                        {'answer_start': 101, 'text': 'Galileo Galilei,'},
#                        {'answer_start': 101, 'text': 'Galileo Galilei'},
#                        {'answer_start': 101, 'text': 'Galileo Galilei'}],
#            'id': '57373f80c3c5551400e51e90',
#            'is_impossible': False,
#            'question': "Whose work  corrected Aristotle's physics in the "
#                        'seventeenth century?'},
#           {'answers': [{'answer_start': 220, 'text': 'impetus'},
#                        {'answer_start': 204, 'text': 'innate force of impetus'},
#                        {'answer_start': 447, 'text': 'gravity'},
#                        {'answer_start': 201,
#                         'text': 'an innate force of impetus'},
#                        {'answer_start': 204, 'text': 'innate force of impetus'},
#                        {'answer_start': 204,
#                         'text': 'innate force of impetus'}],
#            'id': '57373f80c3c5551400e51e91',
#            'is_impossible': False,
#            'question': 'What did objects in forced motion contain according to '
#                        'the late Medieval idea that influence Aristotle?'},
#           {'answers': [{'answer_start': 229, 'text': 'Galileo'},
#                        {'answer_start': 229, 'text': 'Galileo'},
#                        {'answer_start': 101, 'text': 'Galileo Galilei'},
#                        {'answer_start': 229, 'text': 'Galileo'},
#                        {'answer_start': 229, 'text': 'Galileo'},
#                        {'answer_start': 229, 'text': 'Galileo'}],
#            'id': '57373f80c3c5551400e51e92',
#            'is_impossible': False,
#            'question': 'Who experimented by rolling stones and canonballs down '
#                        'a steep incline?'},
#           {'answers': [{'answer_start': 589, 'text': 'friction'},
#                        {'answer_start': 589, 'text': 'friction'},
#                        {'answer_start': 447, 'text': 'gravity'},
#                        {'answer_start': 589, 'text': 'friction'},
#                        {'answer_start': 589, 'text': 'friction'},
#                        {'answer_start': 570, 'text': 'force'}],
#            'id': '57373f80c3c5551400e51e93',
#            'is_impossible': False,
#            'question': 'What force acted on bodies to retard their velocity?'},
#           {'answers': [],
#            'id': '5ad26103d7d075001a428fec',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 101,
#                                   'text': 'Galileo Galilei'}],
#            'question': 'The shortcomings of Aristotelian physics would not be '
#                        'corrected until the 16th century work of whom?'},
#           {'answers': [],
#            'id': '5ad26103d7d075001a428fed',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 101,
#                                   'text': 'Galileo Galilei'}],
#            'question': 'Who was influenced by early Medieval ideas?'},
#           {'answers': [],
#            'id': '5ad26103d7d075001a428fee',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 229, 'text': 'Galileo'}],
#            'question': 'Who constructed an experiment where stones and rocks '
#                        'were rolled down an incline?'},
#           {'answers': [],
#            'id': '5ad26103d7d075001a428fef',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 229, 'text': 'Galileo'}],
#            'question': 'Who argued that objects retain their velocity even '
#                        'when acted on by a force?'}]},
#  {'context': "Newton's First Law of Motion states that objects continue to "
#              'move in a state of constant velocity unless acted upon by an '
#              'external net force or resultant force. This law is an extension '
#              "of Galileo's insight that constant velocity was associated with "
#              'a lack of net force (see a more detailed description of this '
#              'below). Newton proposed that every object with mass has an '
#              'innate inertia that functions as the fundamental equilibrium '
#              '"natural state" in place of the Aristotelian idea of the '
#              '"natural state of rest". That is, the first law contradicts the '
#              'intuitive Aristotelian belief that a net force is required to '
#              'keep an object moving with constant velocity. By making rest '
#              'physically indistinguishable from non-zero constant velocity, '
#              "Newton's First Law directly connects inertia with the concept of "
#              'relative velocities. Specifically, in systems where objects are '
#              'moving with different velocities, it is impossible to determine '
#              'which object is "in motion" and which object is "at rest". In '
#              'other words, to phrase matters more technically, the laws of '
#              'physics are the same in every inertial frame of reference, that '
#              'is, in all frames related by a Galilean transformation.',
#   'qas': [{'answers': [{'answer_start': 0, 'text': 'Newton'},
#                        {'answer_start': 0, 'text': "Newton's"},
#                        {'answer_start': 0, 'text': "Newton's"},
#                        {'answer_start': 0, 'text': "Newton's"},
#                        {'answer_start': 0, 'text': "Newton's"}],
#            'id': '5737432bc3c5551400e51e99',
#            'is_impossible': False,
#            'question': 'Whose First Law of Motion says that unless acted upon '
#                        'be forces, objects would continue to move at a '
#                        'constant velocity?'},
#           {'answers': [{'answer_start': 252, 'text': 'lack of net force'},
#                        {'answer_start': 252, 'text': 'lack of net force'},
#                        {'answer_start': 212,
#                         'text': 'constant velocity was associated with a lack '
#                                 'of net force'},
#                        {'answer_start': 212,
#                         'text': 'constant velocity was associated with a lack '
#                                 'of net force'},
#                        {'answer_start': 252, 'text': 'lack of net force'}],
#            'id': '5737432bc3c5551400e51e9a',
#            'is_impossible': False,
#            'question': 'What insight of Galileo was associated with constant '
#                        'velocity?'},
#           {'answers': [{'answer_start': 319, 'text': 'Newton'},
#                        {'answer_start': 319, 'text': 'Newton'},
#                        {'answer_start': 319, 'text': 'Newton'},
#                        {'answer_start': 319, 'text': 'Newton'},
#                        {'answer_start': 319, 'text': 'Newton'}],
#            'id': '5737432bc3c5551400e51e9b',
#            'is_impossible': False,
#            'question': 'Who proposed that innate intertial is the natural '
#                        'state of objects?'},
#           {'answers': [{'answer_start': 737, 'text': "Newton's First"},
#                        {'answer_start': 526, 'text': 'first law'},
#                        {'answer_start': 737, 'text': "Newton's First Law"},
#                        {'answer_start': 746, 'text': 'First Law'},
#                        {'answer_start': 737, 'text': "Newton's First Law"}],
#            'id': '5737432bc3c5551400e51e9c',
#            'is_impossible': False,
#            'question': 'What law connects relative velocities with inertia?'},
#           {'answers': [{'answer_start': 1065, 'text': 'the same'},
#                        {'answer_start': 1146,
#                         'text': 'a Galilean transformation'},
#                        {'answer_start': 1148,
#                         'text': 'Galilean transformation'},
#                        {'answer_start': 1041,
#                         'text': 'the laws of physics are the same in every '
#                                 'inertial frame of reference'},
#                        {'answer_start': 1065,
#                         'text': 'the same in every inertial frame of '
#                                 'reference'}],
#            'id': '5737432bc3c5551400e51e9d',
#            'is_impossible': False,
#            'question': 'What are the laws of physics of Galileo, in reference '
#                        'to objest in motion and rest?'},
#           {'answers': [],
#            'id': '5ad261a4d7d075001a429048',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 36,
#                                   'text': 'that objects continue to move in a '
#                                           'state of constant velocity unless '
#                                           'acted upon by an external net force '
#                                           'or resultant force'}],
#            'question': "Newton's Second Law of Motion states what?"},
#           {'answers': [],
#            'id': '5ad261a4d7d075001a429049',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 548,
#                                   'text': 'the intuitive Aristotelian belief '
#                                           'that a net force is required to '
#                                           'keep an object moving with constant '
#                                           'velocity'}],
#            'question': 'The second law contradicts what belief?'},
#           {'answers': [],
#            'id': '5ad261a4d7d075001a42904a',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 737,
#                                   'text': "Newton's First Law"}],
#            'question': 'Whose law made rest physically indistinguishable from '
#                        'zero constant velocity?'},
#           {'answers': [],
#            'id': '5ad261a4d7d075001a42904b',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 1053, 'text': 'physics'}],
#            'question': 'What laws are different in every inertial frame of '
#                        'reference?'}]},
#  {'context': 'For instance, while traveling in a moving vehicle at a constant '
#              'velocity, the laws of physics do not change from being at rest. '
#              'A person can throw a ball straight up in the air and catch it as '
#              'it falls down without worrying about applying a force in the '
#              'direction the vehicle is moving. This is true even though '
#              'another person who is observing the moving vehicle pass by also '
#              'observes the ball follow a curving parabolic path in the same '
#              'direction as the motion of the vehicle. It is the inertia of the '
#              'ball associated with its constant velocity in the direction of '
#              "the vehicle's motion that ensures the ball continues to move "
#              'forward even as it is thrown up and falls back down. From the '
#              'perspective of the person in the car, the vehicle and everything '
#              'inside of it is at rest: It is the outside world that is moving '
#              'with a constant speed in the opposite direction. Since there is '
#              'no experiment that can distinguish whether it is the vehicle '
#              'that is at rest or the outside world that is at rest, the two '
#              'situations are considered to be physically indistinguishable. '
#              'Inertia therefore applies equally well to constant velocity '
#              'motion as it does to rest.',
#   'qas': [{'answers': [{'answer_start': 78, 'text': 'laws of physics'},
#                        {'answer_start': 74, 'text': 'the laws of physics'},
#                        {'answer_start': 74, 'text': 'the laws of physics'},
#                        {'answer_start': 74, 'text': 'the laws of physics'},
#                        {'answer_start': 74, 'text': 'the laws of physics'}],
#            'id': '5737477bc3c5551400e51ea3',
#            'is_impossible': False,
#            'question': "What doesn't change from being at rest to movement at "
#                        'a constant velocity?'},
#           {'answers': [{'answer_start': 411, 'text': 'parabolic'},
#                        {'answer_start': 411, 'text': 'parabolic path'},
#                        {'answer_start': 401,
#                         'text': 'a curving parabolic path'},
#                        {'answer_start': 403, 'text': 'curving parabolic path'},
#                        {'answer_start': 403, 'text': 'curving parabolic path'}],
#            'id': '5737477bc3c5551400e51ea4',
#            'is_impossible': False,
#            'question': 'What path does a ball thrown up and down in a moving '
#                        'vehicle take when seen by an outside observer? '},
#           {'answers': [{'answer_start': 770, 'text': 'at rest'},
#                        {'answer_start': 770, 'text': 'at rest'},
#                        {'answer_start': 773, 'text': 'rest'},
#                        {'answer_start': 727,
#                         'text': 'the vehicle and everything inside of it is at '
#                                 'rest:'}],
#            'id': '5737477bc3c5551400e51ea5',
#            'is_impossible': False,
#            'question': 'What sate are things inside of a moving vehicle as '
#                        'seen by a  person inside the vehicle?'},
#           {'answers': [{'answer_start': 1067, 'text': 'Inertia'},
#                        {'answer_start': 1067, 'text': 'Inertia'},
#                        {'answer_start': 1067, 'text': 'Inertia'},
#                        {'answer_start': 1067, 'text': 'Inertia'},
#                        {'answer_start': 1067, 'text': 'Inertia'}],
#            'id': '5737477bc3c5551400e51ea6',
#            'is_impossible': False,
#            'question': 'What applies to equally to constant velocity motion as '
#                        'it does to rest.'},
#           {'answers': [],
#            'id': '5ad26257d7d075001a42909c',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 35,
#                                   'text': 'moving vehicle'}],
#            'question': 'The laws of physics change from being at rest when '
#                        'travelling in a what?'},
#           {'answers': [],
#            'id': '5ad26257d7d075001a42909d',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 708, 'text': 'person'}],
#            'question': 'From the perspective of whom in the car is the vehicle '
#                        'and everything inside of it at rest?'},
#           {'answers': [],
#            'id': '5ad26257d7d075001a42909e',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 962,
#                                   'text': 'the outside world that is at rest'}],
#            'question': 'There are plenty of experiments that can distinguish '
#                        'whether it is the vehicle that s at rest or what?'},
#           {'answers': [],
#            'id': '5ad26257d7d075001a42909f',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 1005, 'text': 'situations'}],
#            'question': 'The two what are considered to be physically '
#                        'distinguishable?'}]},
#  {'context': 'The concept of inertia can be further generalized to explain the '
#              'tendency of objects to continue in many different forms of '
#              'constant motion, even those that are not strictly constant '
#              'velocity. The rotational inertia of planet Earth is what fixes '
#              'the constancy of the length of a day and the length of a year. '
#              'Albert Einstein extended the principle of inertia further when '
#              'he explained that reference frames subject to constant '
#              'acceleration, such as those free-falling toward a gravitating '
#              'object, were physically equivalent to inertial reference frames. '
#              'This is why, for example, astronauts experience weightlessness '
#              "when in free-fall orbit around the Earth, and why Newton's Laws "
#              'of Motion are more easily discernible in such environments. If '
#              'an astronaut places an object with mass in mid-air next to '
#              'himself, it will remain stationary with respect to the astronaut '
#              'due to its inertia. This is the same thing that would occur if '
#              'the astronaut and the object were in intergalactic space with no '
#              'net force of gravity acting on their shared reference frame. '
#              'This principle of equivalence was one of the foundational '
#              'underpinnings for the development of the general theory of '
#              'relativity.',
#   'qas': [{'answers': [{'answer_start': 15, 'text': 'inertia'},
#                        {'answer_start': 15, 'text': 'inertia'},
#                        {'answer_start': 15, 'text': 'inertia'},
#                        {'answer_start': 15, 'text': 'inertia'},
#                        {'answer_start': 15, 'text': 'inertia'}],
#            'id': '573749741c4567190057445d',
#            'is_impossible': False,
#            'question': 'What concept explains why objects continue in constant '
#                        'motion?'},
#           {'answers': [{'answer_start': 197,
#                         'text': 'rotational inertia of planet'},
#                        {'answer_start': 197,
#                         'text': 'rotational inertia of planet Earth'},
#                        {'answer_start': 197, 'text': 'rotational inertia'},
#                        {'answer_start': 197, 'text': 'rotational inertia'},
#                        {'answer_start': 193,
#                         'text': 'The rotational inertia of planet Earth'}],
#            'id': '573749741c4567190057445e',
#            'is_impossible': False,
#            'question': 'What makes day length constant on Earth?'},
#           {'answers': [{'answer_start': 309, 'text': 'Albert Einstein'},
#                        {'answer_start': 309, 'text': 'Albert Einstein'},
#                        {'answer_start': 309, 'text': 'Albert Einstein'},
#                        {'answer_start': 309, 'text': 'Albert Einstein'},
#                        {'answer_start': 309, 'text': 'Albert Einstein'}],
#            'id': '573749741c4567190057445f',
#            'is_impossible': False,
#            'question': 'Who explained that inertial reference frames equaled '
#                        'reference frames subject to constant acceleration?'},
#           {'answers': [{'answer_start': 602, 'text': 'weightlessness'},
#                        {'answer_start': 602, 'text': 'weightlessness'},
#                        {'answer_start': 602, 'text': 'weightlessness'},
#                        {'answer_start': 602, 'text': 'weightlessness'},
#                        {'answer_start': 602, 'text': 'weightlessness'}],
#            'id': '573749741c45671900574460',
#            'is_impossible': False,
#            'question': 'What do astronaughts experience while in free-fall?'},
#           {'answers': [{'answer_start': 1062,
#                         'text': 'principle of equivalence'},
#                        {'answer_start': 1062,
#                         'text': 'principle of equivalence'},
#                        {'answer_start': 1062,
#                         'text': 'principle of equivalence'},
#                        {'answer_start': 1062,
#                         'text': 'principle of equivalence'},
#                        {'answer_start': 1062,
#                         'text': 'principle of equivalence'}],
#            'id': '573749741c45671900574461',
#            'is_impossible': False,
#            'question': 'What was the basis mentioned for the develpment of the '
#                        'general theory of relativity?'},
#           {'answers': [],
#            'id': '5ad262f7d7d075001a4290d4',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 100,
#                                   'text': 'many different forms of constant '
#                                           'motion'}],
#            'question': 'The concept of inertia can explain the tendency of '
#                        'people to continue in what?'},
#           {'answers': [],
#            'id': '5ad262f7d7d075001a4290d5',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 250,
#                                   'text': 'constancy of the length of a day '
#                                           'and the length of a year'}],
#            'question': 'The rotational inertia of planet Mars is what fixes '
#                        'the what?'},
#           {'answers': [],
#            'id': '5ad262f7d7d075001a4290d6',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 309,
#                                   'text': 'Albert Einstein'}],
#            'question': 'Who explained that reference frames subject to '
#                        'constant deceleration?'},
#           {'answers': [],
#            'id': '5ad262f7d7d075001a4290d7',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 602,
#                                   'text': 'weightlessness'}],
#            'question': 'What do astronauts experience when in free-fall orbit '
#                        'around Saturn?'}]},
#  {'context': "Newton's Second Law asserts the direct proportionality of "
#              'acceleration to force and the inverse proportionality of '
#              'acceleration to mass. Accelerations can be defined through '
#              'kinematic measurements. However, while kinematics are '
#              'well-described through reference frame analysis in advanced '
#              'physics, there are still deep questions that remain as to what '
#              'is the proper definition of mass. General relativity offers an '
#              'equivalence between space-time and mass, but lacking a coherent '
#              'theory of quantum gravity, it is unclear as to how or whether '
#              'this connection is relevant on microscales. With some '
#              "justification, Newton's second law can be taken as a "
#              'quantitative definition of mass by writing the law as an '
#              'equality; the relative units of force and mass then are fixed.',
#   'qas': [{'answers': [{'answer_start': 0, 'text': "Newton's Second Law"},
#                        {'answer_start': 0, 'text': "Newton's Second Law"},
#                        {'answer_start': 0, 'text': "Newton's Second Law"},
#                        {'answer_start': 0, 'text': "Newton's Second Law"},
#                        {'answer_start': 0, 'text': "Newton's Second Law"}],
#            'id': '573750f51c45671900574467',
#            'is_impossible': False,
#            'question': 'What describes the proportionality of acceleration to '
#                        'force and mass?'},
#           {'answers': [{'answer_start': 174, 'text': 'kinematic'},
#                        {'answer_start': 174, 'text': 'kinematic measurements'},
#                        {'answer_start': 174, 'text': 'kinematic'},
#                        {'answer_start': 174, 'text': 'kinematic'},
#                        {'answer_start': 174, 'text': 'kinematic'}],
#            'id': '573750f61c45671900574468',
#            'is_impossible': False,
#            'question': 'What kind of measurements define accelerlations?'},
#           {'answers': [{'answer_start': 385, 'text': 'General relativity'},
#                        {'answer_start': 385, 'text': 'General relativity'},
#                        {'answer_start': 385, 'text': 'General relativity'},
#                        {'answer_start': 385, 'text': 'General relativity'},
#                        {'answer_start': 385, 'text': 'General relativity'}],
#            'id': '573750f61c45671900574469',
#            'is_impossible': False,
#            'question': 'What has an equivalence between mass and space-time?'},
#           {'answers': [{'answer_start': 385, 'text': 'General relativity'},
#                        {'answer_start': 469,
#                         'text': 'coherent theory of quantum gravity'},
#                        {'answer_start': 385, 'text': 'General relativity'},
#                        {'answer_start': 385, 'text': 'General relativity'}],
#            'id': '573750f61c4567190057446a',
#            'is_impossible': False,
#            'question': 'What is missing a theory on quantum gravity?'},
#           {'answers': [{'answer_start': 760, 'text': 'fixed'},
#                        {'answer_start': 701, 'text': 'an equality'},
#                        {'answer_start': 760, 'text': 'fixed'},
#                        {'answer_start': 760, 'text': 'fixed'},
#                        {'answer_start': 511, 'text': 'unclear'}],
#            'id': '573750f61c4567190057446b',
#            'is_impossible': False,
#            'question': "In Newton's second law, what are the units of mass and "
#                        'force in relation to microscales?'},
#           {'answers': [],
#            'id': '5ad26382d7d075001a42911a',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 74, 'text': 'force'}],
#            'question': "Newton's Third Law asserts the direct proportionality "
#                        'of acceleration to what?'},
#           {'answers': [],
#            'id': '5ad26382d7d075001a42911b',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 131, 'text': 'mass'}],
#            'question': "Newton's Third Law asserts the inverse proportionality "
#                        'of acceleration to what?'},
#           {'answers': [],
#            'id': '5ad26382d7d075001a42911c',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 174,
#                                   'text': 'kinematic measurements'}],
#            'question': 'Deceleration can be described through what?'},
#           {'answers': [],
#            'id': '5ad26382d7d075001a42911d',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 434,
#                                   'text': 'space-time and mass'}],
#            'question': 'Specific relativity offers an equivalence between '
#                        'what?'}]},
#  {'context': "Newton's Third Law is a result of applying symmetry to "
#              'situations where forces can be attributed to the presence of '
#              'different objects. The third law means that all forces are '
#              'interactions between different bodies,[Note 3] and thus that '
#              'there is no such thing as a unidirectional force or a force that '
#              'acts on only one body. Whenever a first body exerts a force F on '
#              'a second body, the second body exerts a force −F on the first '
#              'body. F and −F are equal in magnitude and opposite in direction. '
#              'This law is sometimes referred to as the action-reaction law, '
#              'with F called the "action" and −F the "reaction". The action and '
#              'the reaction are simultaneous:',
#   'qas': [{'answers': [{'answer_start': 0, 'text': "Newton's Third"},
#                        {'answer_start': 0, 'text': "Newton's Third Law"},
#                        {'answer_start': 0, 'text': "Newton's Third Law"},
#                        {'answer_start': 0, 'text': "Newton's Third Law"},
#                        {'answer_start': 0, 'text': "Newton's Third Law"}],
#            'id': '5737534ec3c5551400e51eab',
#            'is_impossible': False,
#            'question': 'When forces are from the presence of differnet '
#                        'objects, what law gives symmetry?'},
#           {'answers': [{'answer_start': 0, 'text': "Newton's Third"},
#                        {'answer_start': 135, 'text': 'The third law'},
#                        {'answer_start': 135, 'text': 'The third law'},
#                        {'answer_start': 0, 'text': "Newton's Third Law"},
#                        {'answer_start': 0, 'text': "Newton's Third Law"}],
#            'id': '5737534ec3c5551400e51eac',
#            'is_impossible': False,
#            'question': 'What law staes that forces are interactions between '
#                        'bodies?'},
#           {'answers': [{'answer_start': 264, 'text': 'unidirectional'},
#                        {'answer_start': 264, 'text': 'unidirectional force'},
#                        {'answer_start': 264, 'text': 'unidirectional force'},
#                        {'answer_start': 264, 'text': 'unidirectional'},
#                        {'answer_start': 264, 'text': 'unidirectional force'}],
#            'id': '5737534ec3c5551400e51ead',
#            'is_impossible': False,
#            'question': "What kind of force does not exist under Newton's third "
# ...
#                        {'answer_start': 326,
#                         'text': 'the difference in potential energy'},
#                        {'answer_start': 326,
#                         'text': 'the difference in potential energy between '
#                                 'two different locations in space'}],
#            'id': '5737a7351c456719005744f4',
#            'is_impossible': False,
#            'question': 'What is the force between two locations related to?'},
#           {'answers': [{'answer_start': 434, 'text': 'artifact'},
#                        {'answer_start': 434,
#                         'text': 'artifact of the potential field'},
#                        {'answer_start': 431, 'text': 'an artifact'}],
#            'id': '5737a7351c456719005744f5',
#            'is_impossible': False,
#            'question': 'What is the force called rgarding a potential field '
#                        'between two locations?'},
#           {'answers': [],
#            'id': '5ad2895bd7d075001a429982',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 57, 'text': 'associated'}],
#            'question': 'A liberal force that acts on a closed system has what '
#                        'kind of mechanical work?'},
#           {'answers': [],
#            'id': '5ad2895bd7d075001a429983',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 221, 'text': 'conserved'}],
#            'question': 'Net mechanical energy is what in an open system?'},
#           {'answers': [],
#            'id': '5ad2895bd7d075001a429984',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 285, 'text': 'force'}],
#            'question': 'What can not be considered an artifact of the '
#                        'potential field?'},
#           {'answers': [],
#            'id': '5ad2895bd7d075001a429985',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 570,
#                                   'text': 'the contour map of the elevation of '
#                                           'an area'}],
#            'question': 'A flow of water can not be considered an artifact of '
#                        'what?'}]},
#  {'context': 'For certain physical scenarios, it is impossible to model forces '
#              'as being due to gradient of potentials. This is often due to '
#              'macrophysical considerations that yield forces as arising from a '
#              'macroscopic statistical average of microstates. For example, '
#              'friction is caused by the gradients of numerous electrostatic '
#              'potentials between the atoms, but manifests as a force model '
#              'that is independent of any macroscale position vector. '
#              'Nonconservative forces other than friction include other contact '
#              'forces, tension, compression, and drag. However, for any '
#              'sufficiently detailed description, all these forces are the '
#              'results of conservative ones since each of these macroscopic '
#              'forces are the net results of the gradients of microscopic '
#              'potentials.',
#   'qas': [{'answers': [{'answer_start': 58, 'text': 'forces'},
#                        {'answer_start': 58,
#                         'text': 'forces as being due to gradient of '
#                                 'potentials'},
#                        {'answer_start': 58, 'text': 'forces'},
#                        {'answer_start': 58,
#                         'text': 'forces as being due to gradient of '
#                                 'potentials'}],
#            'id': '5737a84dc3c5551400e51f59',
#            'is_impossible': False,
#            'question': 'What is sometimes impossible to model?'},
#           {'answers': [{'answer_start': 81, 'text': 'gradient of potentials'},
#                        {'answer_start': 126,
#                         'text': 'macrophysical considerations that yield '
#                                 'forces as arising from a macroscopic '
#                                 'statistical average of microstates'},
#                        {'answer_start': 81, 'text': 'gradient of potentials.'},
#                        {'answer_start': 81, 'text': 'gradient of potentials'}],
#            'id': '5737a84dc3c5551400e51f5a',
#            'is_impossible': False,
#            'question': 'Why are some forces due to that are impossible to '
#                        'model?'},
#           {'answers': [{'answer_start': 252, 'text': 'friction'},
#                        {'answer_start': 252, 'text': 'friction'},
#                        {'answer_start': 252, 'text': 'friction'},
#                        {'answer_start': 252, 'text': 'friction'}],
#            'id': '5737a84dc3c5551400e51f5b',
#            'is_impossible': False,
#            'question': 'What do electrostatic gradiient potentials create?'},
#           {'answers': [{'answer_start': 430, 'text': 'Nonconservative'},
#                        {'answer_start': 430,
#                         'text': 'Nonconservative forces other than friction'},
#                        {'answer_start': 430, 'text': 'Nonconservative'},
#                        {'answer_start': 430, 'text': 'Nonconservative forces'}],
#            'id': '5737a84dc3c5551400e51f5c',
#            'is_impossible': False,
#            'question': 'Tension, compression, and drag are what kind of '
#                        'forces?'},
#           {'answers': [],
#            'id': '5ad289c2d7d075001a42999e',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 81,
#                                   'text': 'gradient of potentials'}],
#            'question': 'It is always possible to model forces as being due to '
#                        'what?'},
#           {'answers': [],
#            'id': '5ad289c2d7d075001a42999f',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 166, 'text': 'forces'}],
#            'question': 'Micro-physical considerations yield what?'},
#           {'answers': [],
#            'id': '5ad289c2d7d075001a4299a0',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 291,
#                                   'text': 'numerous electrostatic potentials'}],
#            'question': 'Friction is not caused by the gradients of what?'},
#           {'answers': [],
#            'id': '5ad289c2d7d075001a4299a1',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 487,
#                                   'text': 'contact forces, tension, '
#                                           'compression, and drag'}],
#            'question': 'Conservative forces include what?'}]},
#  {'context': 'The connection between macroscopic nonconservative forces and '
#              'microscopic conservative forces is described by detailed '
#              'treatment with statistical mechanics. In macroscopic closed '
#              'systems, nonconservative forces act to change the internal '
#              'energies of the system, and are often associated with the '
#              'transfer of heat. According to the Second law of thermodynamics, '
#              'nonconservative forces necessarily result in energy '
#              'transformations within closed systems from ordered to more '
#              'random conditions as entropy increases.',
#   'qas': [{'answers': [{'answer_start': 134, 'text': 'statistical mechanics'},
#                        {'answer_start': 134, 'text': 'statistical mechanics'},
#                        {'answer_start': 110, 'text': 'detailed'},
#                        {'answer_start': 110,
#                         'text': 'detailed treatment with statistical '
#                                 'mechanics'}],
#            'id': '5737a9afc3c5551400e51f61',
#            'is_impossible': False,
#            'question': 'In what treatment are nonconservative and conservative '
#                        'forces described?'},
#           {'answers': [{'answer_start': 188, 'text': 'nonconservative forces'},
#                        {'answer_start': 229,
#                         'text': 'internal energies of the system'},
#                        {'answer_start': 188, 'text': 'nonconservative forces'},
#                        {'answer_start': 188, 'text': 'nonconservative forces'}],
#            'id': '5737a9afc3c5551400e51f62',
#            'is_impossible': False,
#            'question': 'What changes macroscopic closed system energies?'},
#           {'answers': [{'answer_start': 188, 'text': 'nonconservative forces'},
#                        {'answer_start': 188, 'text': 'nonconservative forces'},
#                        {'answer_start': 188, 'text': 'nonconservative forces'},
#                        {'answer_start': 188, 'text': 'nonconservative forces'}],
#            'id': '5737a9afc3c5551400e51f63',
#            'is_impossible': False,
#            'question': 'What is the exchange of heat associated with?'},
#           {'answers': [{'answer_start': 331, 'text': 'Second'},
#                        {'answer_start': 331,
#                         'text': 'Second law of thermodynamics'},
#                        {'answer_start': 331, 'text': 'Second law'},
#                        {'answer_start': 331, 'text': 'Second'}],
#            'id': '5737a9afc3c5551400e51f64',
#            'is_impossible': False,
#            'question': 'What is the law of thermodynamics associated with '
#                        'closed system heat exchange?'},
#           {'answers': [{'answer_start': 361, 'text': 'nonconservative forces'},
#                        {'answer_start': 361, 'text': 'nonconservative forces'},
#                        {'answer_start': 361, 'text': 'nonconservative forces'},
#                        {'answer_start': 361, 'text': 'nonconservative forces'}],
#            'id': '5737a9afc3c5551400e51f65',
#            'is_impossible': False,
#            'question': 'What makes energy changes in a closed system?'},
#           {'answers': [],
#            'id': '5ad28a57d7d075001a4299b0',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 218,
#                                   'text': 'change the internal energies of the '
#                                           'system'}],
#            'question': 'In macroscopic open systems, non conservative forces '
#                        'act to do what?'},
#           {'answers': [],
#            'id': '5ad28a57d7d075001a4299b1',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 188,
#                                   'text': 'nonconservative forces'}],
#            'question': 'What are often associated with the transfer of cold?'},
#           {'answers': [],
#            'id': '5ad28a57d7d075001a4299b2',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 308, 'text': 'heat'}],
#            'question': 'Conservative forces are often associated with the '
#                        'transfer of what?'},
#           {'answers': [],
#            'id': '5ad28a57d7d075001a4299b3',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 188,
#                                   'text': 'nonconservative forces'}],
#            'question': 'What does not change macroscopic closed systems?'}]},
#  {'context': 'The pound-force has a metric counterpart, less commonly used '
#              'than the newton: the kilogram-force (kgf) (sometimes kilopond), '
#              'is the force exerted by standard gravity on one kilogram of '
#              'mass. The kilogram-force leads to an alternate, but rarely used '
#              'unit of mass: the metric slug (sometimes mug or hyl) is that '
#              'mass that accelerates at 1 m·s−2 when subjected to a force of 1 '
#              'kgf. The kilogram-force is not a part of the modern SI system, '
#              'and is generally deprecated; however it still sees use for some '
#              'purposes as expressing aircraft weight, jet thrust, bicycle '
#              'spoke tension, torque wrench settings and engine output torque. '
#              'Other arcane units of force include the sthène, which is '
#              'equivalent to 1000 N, and the kip, which is equivalent to 1000 '
#              'lbf.',
#   'qas': [{'answers': [{'answer_start': 82, 'text': 'kilogram-force'},
#                        {'answer_start': 4, 'text': 'pound-force'},
#                        {'answer_start': 82, 'text': 'kilogram-force (kgf)'},
#                        {'answer_start': 82, 'text': 'kilogram-force'},
#                        {'answer_start': 78, 'text': 'the kilogram-force ('}],
#            'id': '5737aafd1c456719005744fb',
#            'is_impossible': False,
#            'question': 'What is the metric term less used than the Newton?'},
#           {'answers': [{'answer_start': 114, 'text': 'kilopond'},
#                        {'answer_start': 114, 'text': 'kilopond'},
#                        {'answer_start': 114, 'text': 'kilopond'},
#                        {'answer_start': 114, 'text': 'kilopond'},
#                        {'answer_start': 114, 'text': 'kilopond'}],
#            'id': '5737aafd1c456719005744fc',
#            'is_impossible': False,
#            'question': 'What is the kilogram-force sometimes reffered to as?'},
#           {'answers': [{'answer_start': 274, 'text': 'slug'},
#                        {'answer_start': 267, 'text': 'metric slug'},
#                        {'answer_start': 267, 'text': 'metric slug'},
#                        {'answer_start': 267, 'text': 'metric slug'},
#                        {'answer_start': 263, 'text': 'the metric slug'}],
#            'id': '5737aafd1c456719005744fd',
#            'is_impossible': False,
#            'question': 'What is a very seldom used unit of mass in the metric '
#                        'system?'},
#           {'answers': [{'answer_start': 712, 'text': 'kip'},
#                        {'answer_start': 712, 'text': 'kip'},
#                        {'answer_start': 712, 'text': 'kip'},
#                        {'answer_start': 712, 'text': 'kip'},
#                        {'answer_start': 712, 'text': 'kip'}],
#            'id': '5737aafd1c456719005744fe',
#            'is_impossible': False,
#            'question': 'What seldom used term of a unit of force equal to 1000 '
#                        'pound s of force?'},
#           {'answers': [{'answer_start': 665, 'text': 'sthène'},
#                        {'answer_start': 665, 'text': 'sthène'},
#                        {'answer_start': 665, 'text': 'sthène'},
#                        {'answer_start': 665, 'text': 'sthène'},
#                        {'answer_start': 665, 'text': 'sthène'}],
#            'id': '5737aafd1c456719005744ff',
#            'is_impossible': False,
#            'question': 'What is the seldom used force unit equal to one '
#                        'thousand newtons?'},
#           {'answers': [],
#            'id': '5ad28ad0d7d075001a4299cc',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 4, 'text': 'pound-force'}],
#            'question': 'What does not have a metric counterpart?'},
#           {'answers': [],
#            'id': '5ad28ad0d7d075001a4299cd',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 82,
#                                   'text': 'kilogram-force'}],
#            'question': 'What is the force exerted by standard gravity on one '
#                        'ton of mass?'},
#           {'answers': [],
#            'id': '5ad28ad0d7d075001a4299ce',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 195,
#                                   'text': 'kilogram-force'}],
#            'question': 'What force leads to a commonly used unit of mass?'},
#           {'answers': [],
#            'id': '5ad28ad0d7d075001a4299cf',
#            'is_impossible': True,
#            'plausible_answers': [{'answer_start': 383,
#                                   'text': 'kilogram-force'}],
#            'question': 'What force is part of the modern SI system?'}]}]

# %%
dir_postfix = ''
if use_q:
    dir_postfix += '-q'
if use_random_subq:
    dir_postfix += '-randsubqs'
elif use_subq:
    dir_postfix += '-subqs'
if use_random_suba:
    dir_postfix += '-randsubas'
elif use_suba:
    dir_postfix += '-subas'
dir_postfix += '-nop'

if dir_postfix != '':
    for split in ['dev_distractor', 'train']:
        save_dir = '{}/hotpot-squad{}'.format(DATA_DIR, dir_postfix)
        print('save_dir:', save_dir, 'split:', split)
        os.makedirs(save_dir, exist_ok=True)
        with open(os.path.join(save_dir, 'hotpot_{}_v1.json'.format(split)), 'w') as f:
            json.dump(data_hotpot_squad_new[split.replace('_distractor', '')], f, indent=2)
# Out:
# save_dir: /Users/ethanperez/research/data/hotpot-squad-subqs-subas-nop split: dev_distractor
# save_dir: /Users/ethanperez/research/data/hotpot-squad-subqs-subas-nop split: train
